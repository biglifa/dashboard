# %%
import scrapy as scp
import pandas as pd
import nltk
import numpy as np
import urllib.request as ur
import urllib
import bs4

# %%
#Scrapping
url ="https://www.persee.fr/search?ta=article&q=fuite+des+cerveaux+europe"
url = ur.urlopen(url).read() 
soup = bs4.BeautifulSoup(url)
#text = soup.get_text(strip=True)
#text
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
lignes = soup.findAll("li")
for ligne in lignes:
    print(ligne)
