# %%
import pyodbc as pb
import pandas as pd
import numpy as np
import cx_Oracle as cx
import re

# %%
#Créer la connexion
dsn_tns = cx.makedsn (host='telline.univ-tlse3.fr',port=1521,sid='etupre') 
conn = cx.connect (user = 'bhm0322a', password ='sid2019', dsn = dsn_tns) 
c = conn.cursor ()

# %% [markdown]
# ## Collection

# %%
#Importer la table collection à inserer dans la base
df_collection=pd.read_csv("../data/t_collection.csv")
df_collection.head()
# Out:
#         issn                                          nom_clt  nb_numeros  \
# 0  2262-3353                              Hommes & Migrations         180
# 1  1950-6694                                 Revue économique         320
# 2  1783-1768                   Revue Philosophique de Louvain         441
# 3  1957-7966                                       Population         320
# 4  1777-5418  Revue Européenne des Migrations Internationales          49
#
#    nb_document  pre_année_pub  der_année_pub                       discpline  \
# 0         4523           1987           2008  démographie, science politique
# 1         6776           1950           2002                        économie
# 2        12292           1894           2015                     philosophie
# 3        12794           1946           2004                     démographie
# 4          814           1985           2001                     démographie
#
#                                             editeur
# 0              Musée de l'Histoire de l'Immigration
# 1                                        SciencesPo
# 2                                           Peeters
# 3  INED (Institut national d’études démographiques)
# 4                                      MSH Poitiers

# %%
#Remplacer les NaN
df_collection.fillna('',inplace=True)

# %%
def insertion(cursor,table,value):
    """ Cette fonction,on lui donne un cursor, la table à inserer les données et les données.
        Et elle l'insere
    """
    #Enlever les caractères non prises par oracle
    value=value.encode('ascii', 'ignore').decode('ascii')
    
    #Inserer dans la base
    query="INSERT INTO "+table+" VALUES ("+value+")"
    cursor.execute(query)

# %%
def insertion_ss(cursor,table,df):
    """ Cette fonction, on lui donner un cursor, la table à inserer les données et un dataframe.
        Il prend chaque ligne du dataframe et l'insere dans la table
    """
    #Recupere tous les colonnes du dataframe
    cols=list(df.columns)
    
    for ind,row in df.iterrows():
        value=""
        for c in cols:
            if type(row[c])==str:
                #Oracle ne lis pas tous les caractères. Je remplace les caractères évidents
                v=row[c].replace("'"," ")
                v=v.replace("é","e")
                v=v.replace("à","a")
                v=v.replace("è","e")
                v="'"+v+"'"
            else :
                v=str(row[c])
            value+=v+","
        #Inserer dans la table
        insertion(cursor,table,value[:-1])
        
        #Juste pour connaitre l'avance du programme
        if ind%1000==0:
            print(ind)

# %%
cursor = conn.cursor()
insertion_ss(cursor,"COLLECTION",df_collection)
conn.commit()
cursor.close()
# Out:
# 0

# %%
query = "SELECT * FROM COLLECTION"
df = pd.read_sql(query,conn)
df.head()
# Out:
#         ISSN                                  NOM_COLLECTION  NB_NUMERO  \
# 0  1492-1375                          Sociologie et societes        100
# 1  1773-0201                      Cahiers de la Mediterranee         66
# 2  1777-5809  Reseaux. Communication - Technologie - Societe        126
# 3  1775-3945                    Sante, Societe et Solidarite         18
# 4  1777-5795                             conomie & prevision        181
#
#    NB_DOCUMENT  ANNEE_CREATION  ANNEE_FIN  \
# 0          150            1969       2018
# 1          801            1970       2000
# 2         1876            1983       2000
# 3          360            2002       2010
# 4         1421            1971       2017
#
#                                           DISCIPLINE  \
# 0                                         Sociologie
# 1                                               None
# 2  sciences de l information et de la communicati...
# 3                        economie, science politique
# 4            economie, science politique, sociologie
#
#                                              EDITEUR
# 0             Les Presses de lUniversite de Montreal
# 1                                               None
# 2                                      La decouverte
# 3  Institut de Recherche et Documentation en cono...
# 4                                              INSEE

# %% [markdown]
# ## Article

# %%
df_article=pd.read_csv("../data/t_article.csv")
df_article.head()
# Out:
#    num_doc                                              title  \
# 0        1        La fuite des cerveaux : le cas de l'ex-URSS
# 1        2  Croissance, redistribution et inégalités dans ...
# 2        3  Que nous devons-nous les uns aux autres ? Le c...
# 3        4  Chorafas Dimitri N. — La fuite des cerveaux. L...
# 4        5  Au-delà de la « fuite des cerveaux » : la mobi...
#
#    annee_publication       issn
# 0               1992  2262-3353
# 1               1999  1950-6694
# 2               2008  1783-1768
# 3               1970  1957-7966
# 4               1997  1777-5418

# %%
df_article.fillna('',inplace=True)

# %%
cursor = conn.cursor()
insertion_ss(cursor,"ARTICLE",df_article)
conn.commit()
cursor.close()
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000

# %%
query = "SELECT * FROM ARTICLE"
df = pd.read_sql(query,conn)
df.head()
# Out:
#    NUMERO_ARTICLE                                      TITRE_ARTICLE  \
# 0              81  Bernard Chavance (sous la dir.), Les incertitu...
# 1              82  Mobilite internationale etudiante et insertion...
# 2              83  Abusharaf R. M., 1997 -Sudanese migration to t...
# 3              84  La migration armenienne vers Paris et sa regio...
# 4              85  Laffaire du cerveau. Quelques remarques sur le...
#
#    ANNEE_PUBLICATION       ISSN
# 0               2004  2259-6100
# 1               2013  1705-1495
# 2               1999  1961-8603
# 3               2007  2262-3353
# 4               2006       None

# %% [markdown]
# ## mot_article

# %%
df_mot_article=pd.read_csv("../data/t_mot_article.csv")
df_mot_article.head()
# Out:
#      mot  num_article  frequence
# 0   plus            2          1
# 1  polit            3          1
# 2  europ            4          1
# 3   plus            4          1
# 4    pay            4          1

# %%
cursor = conn.cursor()
insertion_ss(cursor,"article_comporte_mot",df_mot_article)
conn.commit()
cursor.close()
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000

# %%
query = "SELECT * FROM article_comporte_mot"
df = pd.read_sql(query,conn)
df.head()
# Out:
#      MOT  NUMERO_ARTICLE  FREQUENCE_ARTICLE
# 0   tout             221                  3
# 1  europ             222                  2
# 2    pay             222                  2
# 3  europ             223                  3
# 4    pay             223                  1

# %% [markdown]
# ## Auteur

# %%
df_auteur=pd.read_csv("../data/t_auteur.csv")
df_auteur.head()
# Out:
#       num                 nom  annee_naissance  annee_decès  \
# 0  414356     Kortunov Andrei              NaN          NaN
# 1  140232     Bouyssou Rachel              NaN          NaN
# 2   24789   Docquier Frédéric              NaN          NaN
# 3   61222    Rapoport Hillel            1963.0          NaN
# 4  731465  Chauvier Stéphane            1959.0          NaN
#
#                                           profession
# 0                                                NaN
# 1                                                NaN
# 2                    Docteur en sciences économiques
# 3                                                NaN
# 4  Maître de conférences de philosophie à l'Unive...

# %%
df_auteur.fillna('',inplace=True)

# %%
cursor = conn.cursor()
insertion_ss(cursor,"auteur",df_auteur)
conn.commit()
cursor.close()
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000

# %%
query = "SELECT * FROM auteur"
df = pd.read_sql(query,conn)
df
# Out:
#      NUMERO_AUTEUR          NOM_PRENOM  ANNEE_DE_NAISSANCE  ANNEE_DE_DECES  \
# 0           395042      Acselrad Henri                 NaN             NaN
# 1           395043       Mello Cecilia                 NaN             NaN
# 2           395066    Vaucher Philippe                 NaN             NaN
# 3           247976         Veyne Paul               1930.0             NaN
# 4           177537             Song Wu                 NaN             NaN
# ...            ...                 ...                 ...             ...
# 7581        396619      Smith Marc H.               1963.0             NaN
# 7582        158155    Couturas Claire               1963.0             NaN
# 7583         49821      Bonaventure N.                 NaN             NaN
# 7584         49820            Riche N.                 NaN             NaN
# 7585      00099991  Santerre Christine                 NaN             NaN
#
#                                              PROFESSION
# 0     Professeur d urbanisme et d amenagement du ter...
# 1                                                  None
# 2                                                  None
# 3                                             Historien
# 4                                                  None
# ...                                                 ...
# 7581                         Docteur en histoire (Paris
# 7582                                               None
# 7583                                               None
# 7584                                               None
# 7585                                               None
#
# [7586 rows x 5 columns]

# %% [markdown]
# ## Redige

# %%
df_redige=pd.read_csv("../data/t_redige.csv")
df_redige.head()
# Out:
#       num  num_doc
# 0  414356        1
# 1  140232        1
# 2   24789        2
# 3   61222        2
# 4  731465        3

# %%
cursor = conn.cursor()
insertion_ss(cursor,"redige",df_redige)
conn.commit()
cursor.close()
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000

# %%
query = "SELECT * FROM redige"
df = pd.read_sql(query,conn)
df
# Out:
#       NUMERO_AUTEUR  NUMERO_ARTICLE
# 0           0004421             443
# 1           0004422             443
# 2             59771             444
# 3            226008             445
# 4             51235             446
# ...             ...             ...
# 10637         49819            9999
# 10638         49280            9999
# 10639         49820            9999
# 10640         49806            9999
# 10641      00099991           10000
#
# [10642 rows x 2 columns]

# %% [markdown]
# ## Nationalite

# %%
df_nationalite=pd.read_csv('../data/t_nationalite.csv')
df_nationalite.head()
# Out:
#       num nom_pays
# 0   33007   france
# 1  259994   france
# 2  249315   france
# 3  215901   france
# 4  234171   france

# %%
cursor = conn.cursor()
insertion_ss(cursor,"nationalite",df_nationalite)
conn.commit()
cursor.close()
# Out:
# 0

# %%
query = "SELECT * FROM nationalite"
df = pd.read_sql(query,conn)
df
# Out:
#     NUMERO_AUTEUR      NOM_PAYS
# 0          163274   afghanistan
# 1          288736     argentina
# 2           34139         benin
# 3          234869  burkina faso
# 4          197551       burundi
# ..            ...           ...
# 325        401478       reunion
# 326        174724       romania
# 327        253971     sri lanka
# 328        227422      thailand
# 329          1725       uruguay
#
# [330 rows x 2 columns]

# %% [markdown]
# ## Pays_article

# %%
df_pays_article=pd.read_csv("../data/t_pays_article.csv")
df_pays_article.head()
# Out:
#    nom_pays  num_article
# 0   réunion           15
# 1    poland           36
# 2      oman           43
# 3  pakistan           62
# 4     egypt           66

# %%
cursor = conn.cursor()
insertion_ss(cursor,"PAYS_ARTICLE",df_pays_article)
conn.commit()
cursor.close()
# Out:
# 0

# %%
query = "SELECT * FROM PAYS_ARTICLE"
df = pd.read_sql(query,conn)
df
# Out:
#      NOM_PAYS  NUMERO_ARTICLE
# 0     reunion              15
# 1      poland              36
# 2        oman              43
# 3    pakistan              62
# 4       egypt              66
# ..        ...             ...
# 890     egypt            9935
# 891   finland            9968
# 892  portugal            9968
# 893      chad            9972
# 894   reunion            9974
#
# [895 rows x 2 columns]

# %%
#Fermer la connexion
conn.close()
